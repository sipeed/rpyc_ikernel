# %%
import platform
print(platform.uname())
import time
print(time.asctime())
# Out:
# uname_result(system='Linux', node='linux-lab', release='5.4.0-56-generic', version='#62-Ubuntu SMP Mon Nov 23 19:20:19 UTC 2020', machine='x86_64', processor='x86_64')
# Tue Dec 15 15:04:08 2020

# %%
print('test')
raise Exception('HELLO')
# Out:
# 2020-12-15 15:04:08,348 - rpyc_ikernel - ERROR - HELLO
#
# ========= Remote Traceback (1) =========
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/rpyc/core/protocol.py", line 320, in _dispatch_request
#     res = self._HANDLERS[handler](self, *args)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/rpyc/core/protocol.py", line 593, in _handle_call
#     return obj(*args, **dict(kwargs))
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/rpyc/core/service.py", line 152, in execute
#     execute(text, self.namespace)
#   File "<string>", line 2, in <module>
# Exception: HELLO
# test

# %%
255 / 0
# Out:
# 2020-12-15 15:04:21,344 - rpyc_ikernel - ERROR - division by zero
#
# ========= Remote Traceback (1) =========
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/rpyc/core/protocol.py", line 320, in _dispatch_request
#     res = self._HANDLERS[handler](self, *args)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/rpyc/core/protocol.py", line 593, in _handle_call
#     return obj(*args, **dict(kwargs))
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/rpyc/core/service.py", line 152, in execute
#     execute(text, self.namespace)
#   File "<string>", line 1, in <module>
# ZeroDivisionError: division by zero

# %%
tmp = 255 / 5
print(tmp)
import os
print(os.getpid())
import threading
print(threading.enumerate())
# Out:
# 51.0
# 2207
# [<_MainThread(MainThread, started 140307515451200)>, <Thread(Thread-6, started daemon 140307500316416)>]

# %%
import sys
sys.exit()

import time
while True:
    time.sleep(1)
    print(time.time())
    
# dont use such as code
'''
while True:
    time.sleep(1)
    pass
'''

# %%
import time
for i in range(5000):
    print(time.time())
# Out:
# 1608015952.4572566
# 1608015952.5012357
# 1608015952.502813
# 1608015952.5040085
# 1608015952.5050874
# 1608015952.5060632
# 1608015952.5069377
# 1608015952.5078192
# 1608015952.5089893
# 1608015952.5103583
# 1608015952.5113409
# 1608015952.5122695
# 1608015952.513144
# 1608015952.5139828
# 1608015952.514817
# 1608015952.5156531
# 1608015952.5167146
# 1608015952.5177872
# 1608015952.518843
# 1608015952.5197914
# 1608015952.5208087
# 1608015952.5219293
# 1608015952.5228722
# 1608015952.523694
# 1608015952.524503
# 1608015952.5255504
# 1608015952.5268192
# 1608015952.5278952
# 1608015952.5287392
# 1608015952.529566
# 1608015952.530375
# 1608015952.5311852
# 1608015952.5320451
# 1608015952.5329537
# 1608015952.5339794
# 1608015952.5350006
# 1608015952.5359774
# 1608015952.5369196
# 1608015952.5378306
# 1608015952.5386524
# 1608015952.539455
# 1608015952.5402648
# 1608015952.5411549
# 1608015952.5422244
# 1608015952.5434532
# 1608015952.544658
# 1608015952.545902
# 1608015952.5471396
# ...
