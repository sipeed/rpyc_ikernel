# %%
$connect("192.168.43.144")

import platform
print(platform.uname())
# Out:
# uname_result(system='Linux', node='sipeed', release='4.9.118', version='#110 PREEMPT Fri Dec 25 08:16:04 UTC 2020', machine='armv7l', processor='')

# %%
from maix import display, camera

import time

# display.clear_output = False
display.local_show = False

from PIL import ImageDraw

while True:
    tmp = (camera.capture())
    draw = ImageDraw.Draw(tmp)
    draw.text((10, 10), str(time.time()), (255, 255, 255))
    display.show(tmp)
# Out:
# 2021-01-03 17:11:48,766 - rpyc_ikernel - ERROR -
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
# KeyboardInterrupt
#
# 2021-01-03 17:11:48,767 - rpyc_ikernel - INFO - stream has been closed
